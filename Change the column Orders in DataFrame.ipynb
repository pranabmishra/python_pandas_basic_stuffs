# %% [markdown]
# # How to change the column orders in the DataFrame?

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./dataset/nba.csv')

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# # By Using iloc and Slicer

# %%
df.iloc[:,[0,1,2,8,4,5,6,7,3]]
# Out:
#               Name            Team  Number     Salary   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0  7730337.0  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0  6796117.0  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0        NaN  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0  1148640.0  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0  5000000.0  29.0   6-10   231.0
# ..             ...             ...     ...        ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0  2433333.0  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0   900000.0  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0  2900000.0  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0   947276.0  26.0    7-0   231.0
# 457            NaN             NaN     NaN        NaN   NaN    NaN     NaN
#
#                College Position
# 0                Texas       PG
# ...

# %% [markdown]
# # By using Loc and Column Name

# %%
df.loc[:,['Name','Team','College','Position','Age','Height','Weight','Salary','Number']]
# Out:
#               Name            Team            College Position   Age Height  \
# 0    Avery Bradley  Boston Celtics              Texas       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics          Marquette       SF  25.0    6-6
# 2     John Holland  Boston Celtics  Boston University       SG  27.0    6-5
# 3      R.J. Hunter  Boston Celtics      Georgia State       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics                NaN       PF  29.0   6-10
# ..             ...             ...                ...      ...   ...    ...
# 453   Shelvin Mack       Utah Jazz             Butler       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz                NaN       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz                NaN        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz             Kansas        C  26.0    7-0
# 457            NaN             NaN                NaN      NaN   NaN    NaN
#
#      Weight     Salary  Number
# ...

# %% [markdown]
# ## Selecting few rows and 4 column

# %%
df.loc[:20,['Name','Team','College','Salary']]
# Out:
#                        Name            Team            College      Salary
# 0             Avery Bradley  Boston Celtics              Texas   7730337.0
# 1               Jae Crowder  Boston Celtics          Marquette   6796117.0
# 2              John Holland  Boston Celtics  Boston University         NaN
# 3               R.J. Hunter  Boston Celtics      Georgia State   1148640.0
# 4             Jonas Jerebko  Boston Celtics                NaN   5000000.0
# 5              Amir Johnson  Boston Celtics                NaN  12000000.0
# 6             Jordan Mickey  Boston Celtics                LSU   1170960.0
# 7              Kelly Olynyk  Boston Celtics            Gonzaga   2165160.0
# 8              Terry Rozier  Boston Celtics         Louisville   1824360.0
# 9              Marcus Smart  Boston Celtics     Oklahoma State   3431040.0
# 10          Jared Sullinger  Boston Celtics         Ohio State   2569260.0
# ...

# %% [markdown]
# # Subsetting columns by list

# %%
df[['Name', 'College', 'Team',   'Salary','Number', 'Position', 'Age', 'Height', 'Weight']]
# Out:
#               Name            College            Team     Salary  Number  \
# 0    Avery Bradley              Texas  Boston Celtics  7730337.0     0.0
# 1      Jae Crowder          Marquette  Boston Celtics  6796117.0    99.0
# 2     John Holland  Boston University  Boston Celtics        NaN    30.0
# 3      R.J. Hunter      Georgia State  Boston Celtics  1148640.0    28.0
# 4    Jonas Jerebko                NaN  Boston Celtics  5000000.0     8.0
# ..             ...                ...             ...        ...     ...
# 453   Shelvin Mack             Butler       Utah Jazz  2433333.0     8.0
# 454      Raul Neto                NaN       Utah Jazz   900000.0    25.0
# 455   Tibor Pleiss                NaN       Utah Jazz  2900000.0    21.0
# 456    Jeff Withey             Kansas       Utah Jazz   947276.0    24.0
# 457            NaN                NaN             NaN        NaN     NaN
#
#     Position   Age Height  Weight
# 0         PG  25.0    6-2   180.0
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...
