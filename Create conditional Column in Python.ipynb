# %% [markdown]
# # How to create conditional Column in Python?

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('./dataset/nba.csv')

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# ## Method - 1

# %% [markdown]
# ## With Pandas Where Function

# %%
df['new_1'] = df.Age.where(df.Age > 25,'class_1')

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary    new_1
# 0                Texas  7730337.0  class_1
# 1            Marquette  6796117.0  class_1
# 2    Boston University        NaN       27
# 3        Georgia State  1148640.0  class_1
# 4                  NaN  5000000.0       29
# ..                 ...        ...      ...
# 453             Butler  2433333.0       26
# 454                NaN   900000.0  class_1
# 455                NaN  2900000.0       26
# 456             Kansas   947276.0       26
# 457                NaN        NaN  class_1
#
# [458 rows x 10 columns]

# %% [markdown]
# ## Method - 2

# %% [markdown]
# ## With numpy where function

# %%
df['new_2'] = np.where(
    (df.Team == 'Boston Celtics') & (df.Age > 25),
    'Class_2','other')

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary    new_1    new_2
# 0                Texas  7730337.0  class_1    other
# 1            Marquette  6796117.0  class_1    other
# 2    Boston University        NaN       27  Class_2
# 3        Georgia State  1148640.0  class_1    other
# 4                  NaN  5000000.0       29  Class_2
# ..                 ...        ...      ...      ...
# 453             Butler  2433333.0       26    other
# 454                NaN   900000.0  class_1    other
# 455                NaN  2900000.0       26    other
# 456             Kansas   947276.0       26    other
# 457                NaN        NaN  class_1    other
#
# [458 rows x 11 columns]

# %% [markdown]
# # Method 3

# %% [markdown]
# ## With Numpy Select Function

# %%
df.head(2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary    new_1  new_2
# 0      Texas  7730337.0  class_1  other
# 1  Marquette  6796117.0  class_1  other

# %%
filters = [(df.Team == 'Boston Celtics') & (df.Age >= 25),
           (df.Team == 'Utah Jazz') & (df.Age >= 26),
           (df.Age < 25)]

values = ['Grade_1','Grade_2','Grade_3']

# %%
df['Grade'] = np.select(filters,values, default = 'no_grade')

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary    new_1    new_2     Grade
# 0                Texas  7730337.0  class_1    other   Grade_1
# 1            Marquette  6796117.0  class_1    other   Grade_1
# 2    Boston University        NaN       27  Class_2   Grade_1
# 3        Georgia State  1148640.0  class_1    other   Grade_3
# 4                  NaN  5000000.0       29  Class_2   Grade_1
# ..                 ...        ...      ...      ...       ...
# 453             Butler  2433333.0       26    other   Grade_2
# 454                NaN   900000.0  class_1    other   Grade_3
# 455                NaN  2900000.0       26    other   Grade_2
# 456             Kansas   947276.0       26    other   Grade_2
# 457                NaN        NaN  class_1    other  no_grade
#
# [458 rows x 12 columns]
